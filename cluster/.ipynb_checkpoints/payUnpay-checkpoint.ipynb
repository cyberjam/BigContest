# %%
import pandas as pd
import numpy as np

# %%
pay_raw = pd.read_csv('../BigContest/train_payment.csv')

# %%
pay = pay_raw

# %%
pay.dtypes
# Out:
# day               int64
# acc_id            int64
# amount_spent    float64
# dtype: object

# %%
pay.head()
pay.count()
# Out:
# day             66432
# acc_id          66432
# amount_spent    66432
# dtype: int64

# %%
pay.acc_id.duplicated().sum()
# Out:
# 42706

# %%
66432-42706
# Out:
# 23726

# %%
grp_sum_pay= pay.groupby('acc_id',as_index=False).sum().drop(columns = 'day')
grp_sum_pay.count()
# Out:
# acc_id          23726
# amount_spent    23726
# dtype: int64

# %%
paid = grp_sum_pay[grp_sum_pay['amount_spent']>0]
paid
# Out:
#        acc_id  amount_spent
# 0           8      1.404644
# 1          20      0.896531
# 2          21      2.695461
# 3          38      6.309749
# 4          41      0.035204
# ...       ...           ...
# 23721  130447      3.215308
# 23722  130449      0.348521
# 23723  130469      0.360255
# 23724  130470      1.392909
# 23725  130473      2.955971
#
# [23726 rows x 2 columns]

# %%
unPaid = grp_sum_pay[grp_sum_pay['amount_spent']==0]
unPaid
# Out:
# Empty DataFrame
# Columns: [acc_id, amount_spent]
# Index: []

# %%
label = pd.read_csv('../BigContest/train_label.csv')

# %%
# label=label.drop(columns='amount_spent')

# %%
test = label.merge(paid,how='outer',on='acc_id')

# %%
test[test['amount_spent'].isnull()==True].count()

# pay_unpay = test[test['amount_spent'].isnull()==True]

# %%
test[['amount_spent']].isnull().sum()
# Out:
# amount_spent    16274
# dtype: int64

# %%
label[label['amount_spent']==0].count()
# label_unpay= label[label['amount_spent']==0]
# Out:
# acc_id           16438
# survival_time    16438
# amount_spent     16438
# dtype: int64

# %%
16438-16274
# Out:
# 164

# %%
label_unpay
# Out:
#        acc_id  survival_time  amount_spent
# 7        7678              5           0.0
# 9      116489             23           0.0
# 10      80681             23           0.0
# 14      54944              6           0.0
# 16      84274             64           0.0
# ...       ...            ...           ...
# 39974   63780             64           0.0
# 39977    2036              1           0.0
# 39986   31529             15           0.0
# 39987   53989             51           0.0
# 39998   99716             39           0.0
#
# [16438 rows x 3 columns]

# %%
pay_unpay
# Out:
#        acc_id  survival_time  amount_spent
# 11      91444             64           NaN
# 17      82976             33           NaN
# 27      89354              1           NaN
# 29      86978             52           NaN
# 34      71096             64           NaN
# ...       ...            ...           ...
# 39985   14925              1           NaN
# 39987   53989             51           NaN
# 39992   64094             64           NaN
# 39996   83195             64           NaN
# 39998   99716             39           NaN
#
# [16274 rows x 3 columns]

# %%
pay_unpay = pay_unpay.fillna(1)

# %%
pay_unpay
# Out:
#        acc_id  survival_time  amount_spent
# 11      91444             64           1.0
# 17      82976             33           1.0
# 27      89354              1           1.0
# 29      86978             52           1.0
# 34      71096             64           1.0
# ...       ...            ...           ...
# 39985   14925              1           1.0
# 39987   53989             51           1.0
# 39992   64094             64           1.0
# 39996   83195             64           1.0
# 39998   99716             39           1.0
#
# [16274 rows x 3 columns]

# %%
test_2= label_unpay.merge(pay_unpay,how='outer',on = 'acc_id')

# %%
3826-3662
# Out:
# 164

# %%
label_unpay.acc_id.duplicated().sum()
# Out:
# 0

# %%
pay_unpay.acc_id.duplicated().sum()
# Out:
# 0

# %%
test_2.isnull().sum()
# Out:
# acc_id                0
# survival_time_x    3662
# amount_spent_x     3662
# survival_time_y    3826
# amount_spent_y     3826
# dtype: int64

# %%
label_unpay[(label_unpay['amount_spent']==0)&(pay_unpay[pay_unpay['amount_spent']==1])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\Bigcon\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1253         try:
# -> 1254             result = op(x, y)
#    1255         except TypeError:
#
# ~\Anaconda3\envs\Bigcon\lib\site-packages\pandas\core\ops\roperator.py in rand_(left, right)
#      52 def rand_(left, right):
# ---> 53     return operator.and_(right, left)
#      54
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\Bigcon\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1268                 try:
# -> 1269                     result = libops.scalar_binop(x, y, op)
#    1270                 except (
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_binop()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'double'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-cb92f8b8ac9a> in <module>
# ----> 1 label_unpay[(label_unpay['amount_spent']==0)&(pay_unpay[pay_unpay['amount_spent']==1])]
#
# ~\Anaconda3\envs\Bigcon\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#    1497             pass_op = op if axis in [0, "columns", None] else na_op
#    1498             return _combine_series_frame(
# -> 1499                 self, other, pass_op, fill_value=fill_value, axis=axis, level=level
#    1500             )
#    1501         else:
#
# ~\Anaconda3\envs\Bigcon\lib\site-packages\pandas\core\ops\__init__.py in _combine_series_frame(self, other, func, fill_value, axis, level)
#    1386             return self._combine_match_index(other, func, level=level)
#    1387         else:
# -> 1388             return self._combine_match_columns(other, func, level=level)
#    1389     else:
#    1390         if not len(other):
#
# ~\Anaconda3\envs\Bigcon\lib\site-packages\pandas\core\frame.py in _combine_match_columns(self, other, func, level)
#    5390         left, right = self.align(other, join="outer", axis=1, level=level, copy=False)
#    5391         assert left.columns.equals(right.index)
# -> 5392         return ops.dispatch_to_series(left, right, func, axis="columns")
#    5393
#    5394     def _combine_const(self, other, func):
#
# ~\Anaconda3\envs\Bigcon\lib\site-packages\pandas\core\ops\__init__.py in dispatch_to_series(left, right, func, str_rep, axis)
#     594         raise NotImplementedError(right)
#     595
# --> 596     new_data = expressions.evaluate(column_op, str_rep, left, right)
#     597
#     598     result = left._constructor(new_data, index=left.index, copy=False)
#
# ~\Anaconda3\envs\Bigcon\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     218     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     219     if use_numexpr:
# --> 220         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     221     return _evaluate_standard(op, op_str, a, b)
#     222
#
# ~\Anaconda3\envs\Bigcon\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      68         _store_test_result(False)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#      72
#
# ~\Anaconda3\envs\Bigcon\lib\site-packages\pandas\core\ops\__init__.py in column_op(a, b)
#     582
#     583         def column_op(a, b):
# --> 584             return {i: func(a.iloc[:, i], b.iloc[i]) for i in range(len(a.columns))}
#     585
#     586     elif isinstance(right, ABCSeries):
#
# ~\Anaconda3\envs\Bigcon\lib\site-packages\pandas\core\ops\__init__.py in <dictcomp>(.0)
#     582
#     583         def column_op(a, b):
# --> 584             return {i: func(a.iloc[:, i], b.iloc[i]) for i in range(len(a.columns))}
#     585
#     586     elif isinstance(right, ABCSeries):
#
# ~\Anaconda3\envs\Bigcon\lib\site-packages\pandas\core\ops\roperator.py in rand_(left, right)
#      51
#      52 def rand_(left, right):
# ---> 53     return operator.and_(right, left)
#      54
#      55
#
# ~\Anaconda3\envs\Bigcon\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#    1319         #   integer dtypes.  Otherwise these are boolean ops
#    1320         filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
# -> 1321         res_values = na_op(self.values, ovalues)
#    1322         unfilled = self._constructor(res_values, index=self.index, name=res_name)
#    1323         filled = filler(unfilled)
#
# ~\Anaconda3\envs\Bigcon\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1278                         "cannot compare a dtyped [{dtype}] array "
#    1279                         "with a scalar of type [{typ}]".format(
# -> 1280                             dtype=x.dtype, typ=type(y).__name__
#    1281                         )
#    1282                     )
#
# TypeError: cannot compare a dtyped [float64] array with a scalar of type [bool]

# %%
label_unpay.equals(pay_unpay)
# Out:
# False
