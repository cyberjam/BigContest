# %% [markdown]
# # 낚시와 생존 상관

# %%
import pandas as pd
import numpy as np

# %%
activity_raw = pd.read_csv('BigContest/train_activity.csv')

# %%
activity_raw.dtypes
# Out:
# day                    int64
# acc_id                 int64
# char_id                int64
# server                object
# playtime             float64
# npc_kill             float64
# solo_exp             float64
# party_exp            float64
# quest_exp            float64
# boss_monster           int64
# death                float64
# revive               float64
# exp_recovery         float64
# fishing              float64
# private_shop         float64
# game_money_change    float64
# enchant_count        float64
# dtype: object

# %%
activity = activity_raw[['acc_id','fishing','day']].sort_values(['acc_id','day'],ascending=True)
activity
# Out:
#          acc_id   fishing  day
# 37347         2  0.000000    1
# 91650         2  0.000000    2
# 146424        2  0.000000    3
# 201150        2  0.000000    4
# 256769        2  0.000000    5
# 311844        2  0.000000    6
# 367212        2  0.000000    7
# 423613        2  0.000000    8
# 479282        2  0.000000    9
# 534937        2  0.000000   10
# 591580        2  0.000000   11
# 649403        2  0.000000   12
# 706156        2  0.000000   13
# 762802        2  0.000000   14
# 818886        2  0.000000   15
# 874413        2  0.000000   16
# 929766        2  0.000000   17
# 985970        2  0.000000   18
# 1042897       2  0.000000   19
# 1100000       2  0.000000   20
# 1155765       2  0.000000   21
# 1213442       2  0.000000   22
# 1270683       2  0.000000   23
# 1327686       2  0.000000   24
# 1386509       2  0.000000   25
# 1447391       2  0.000000   26
# 1508225       2  0.000000   27
# 1571479       2  0.000000   28
# 470137        5  0.000000    9
# ...

# %%
act_grp= activity.groupby(['acc_id']).sum().drop(columns = 'day')
act_grp
# Out:
#           fishing
# acc_id
# 2        0.000000
# 5        0.396324
# 8        4.868347
# 17       9.332509
# 20       4.349843
# 21      15.033519
# 31       0.000000
# 38      26.549264
# 41       0.000000
# 43       1.279431
# 50       0.000000
# 53       0.000000
# 54       0.000000
# 59       0.000000
# 62       6.772344
# 63      14.744245
# 65       0.000000
# 66      20.500558
# 67       0.327827
# 69       4.327169
# 75       2.364867
# 76       0.000000
# 77       0.000000
# 79       0.000000
# 81      15.286569
# 86       0.000000
# 91      35.278617
# 92       0.000000
# 97       0.000000
# 98      20.673142
# ...           ...
# 130383   0.000000
# 130384   0.000000
# 130386   7.582530
# 130390   0.000000
# 130391  13.210461
# 130392   2.534449
# 130398   1.550296
# 130401   4.388555
# 130403   0.000000
# 130405   5.276719
# 130408   0.000000
# 130411   7.408919
# 130413   0.000000
# 130414  16.312041
# 130415   1.977155
# 130416   0.000000
# 130420   1.810180
# ...

# %%
act_grp.dtypes
# act_grp['acc_id'] = act_grp.index
# act_grp
# act_grp.drop(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-90c22e6f4dd5> in <module>
#       2 act_grp['acc_id'] = act_grp.index
#       3 act_grp
# ----> 4 act_grp.drop(index)
#
# NameError: name 'index' is not defined

# %%
label_raw = pd.read_csv('BigContest/train_label.csv')

# %%
label_raw.dtypes
# Out:
# acc_id             int64
# survival_time      int64
# amount_spent     float64
# dtype: object

# %%
label = label_raw[['acc_id','survival_time']]
label
# Out:
#        acc_id  survival_time
# 0       27835             64
# 1       12351             64
# 2      125437             55
# 3      104483             64
# 4        4704             20
# 5        3277             50
# 6      118874             64
# 7        7678              5
# 8      124997             46
# 9      116489             23
# 10      80681             23
# 11      91444             64
# 12     113169             64
# 13     105928             64
# 14      54944              6
# 15      41188             64
# 16      84274             64
# 17      82976             33
# 18     106636              9
# 19      99546             25
# 20      78232             15
# 21      68702             64
# 22      36632             31
# 23      83478             64
# 24      33151             29
# 25      25482             64
# 26       3043             64
# 27      89354              1
# 28      63879             64
# 29      86978             52
# ...       ...            ...
# ...

# %%
lbl_act_mrg= label.merge(act_grp,how='inner',on='acc_id').sort_values(['survival_time','fishing'],ascending=False)
lbl_act_mrg#.sort_values(['survival_time','fishing'],ascending=False)
# Out:
#        acc_id  survival_time    fishing
# 20507   87935             64  84.314561
# 1273    86618             64  80.935638
# 16840   60263             64  78.445075
# 12818  125051             64  78.416278
# 3803    34036             64  77.929851
# 9973     8169             64  77.644765
# 1453    50692             64  77.166948
# 10843   35240             64  77.164973
# 11344   75339             64  77.126459
# 8254    40292             64  76.687315
# 20741  115028             64  76.637424
# 1131    44324             64  76.621386
# 10759   93583             64  75.823248
# 273     38539             64  75.793345
# 2661   125074             64  75.112646
# 14600   86622             64  74.554759
# 11538   33365             64  74.547491
# 32636   47942             64  74.460863
# 15926   15537             64  74.452488
# 13358  128261             64  74.349428
# 39685    2272             64  74.336273
# 38833   84999             64  74.087174
# ...

# %%
lbl_act_mrg.drop(columns = 'acc_id')
# Out:
#        survival_time    fishing
# 20507             64  84.314561
# 1273              64  80.935638
# 16840             64  78.445075
# 12818             64  78.416278
# 3803              64  77.929851
# 9973              64  77.644765
# 1453              64  77.166948
# 10843             64  77.164973
# 11344             64  77.126459
# 8254              64  76.687315
# 20741             64  76.637424
# 1131              64  76.621386
# 10759             64  75.823248
# 273               64  75.793345
# 2661              64  75.112646
# 14600             64  74.554759
# 11538             64  74.547491
# 32636             64  74.460863
# 15926             64  74.452488
# 13358             64  74.349428
# 39685             64  74.336273
# 38833             64  74.087174
# 22968             64  73.879117
# 29133             64  73.755989
# 5315              64  73.518503
# 17232             64  73.499937
# 29100             64  73.382616
# 21985             64  72.869840
# ...

# %%
grp_df = pd.DataFrame({'survival_time':lbl_act_mrg['survival_time'], 'fishing':lbl_act_mrg['fishing']})

# %%
grp_df.plot.scatter(x='survival_time',y='fishing')
