# %% [markdown]
# ## Day2 가설 : 막피 당한 유저는 이탈률이 높을까?

# %%
import pandas as pd

# %%
combat = pd.read_csv('BigContest/train_combat.csv')

# %%
combat.dtypes
# Out:
# day                      int64
# acc_id                   int64
# char_id                  int64
# server                  object
# class                    int64
# level                    int64
# pledge_cnt             float64
# random_attacker_cnt    float64
# random_defender_cnt    float64
# temp_cnt               float64
# same_pledge_cnt        float64
# etc_cnt                float64
# num_opponent           float64
# dtype: object

# %%
# 날짜, 유저, 캐릭터, 막피 공격 받은 횟수
rnd_defen= combat[['day','acc_id','char_id','random_defender_cnt']]
rnd_defen
# Out:
#          day  acc_id  char_id  random_defender_cnt
# 0          1   13809    54861             0.000000
# 1          1   13809   256332             0.000000
# 2          1   13809   307293             0.000000
# 3          1   13809   374964             0.000000
# 4          1   13809   117917             0.000000
# 5          1   62835   129987             0.000000
# 6          1   62835    74659             0.000000
# 7          1   62835   179366             0.000000
# 8          1   62835   157318             0.000000
# 9          1   62835   394244             0.000000
# 10         1   54241   316971             0.000000
# 11         1   88683   299973             0.000000
# 12         1   80158   211359             1.183064
# 13         1   30386   309343             0.000000
# 14         1   30386    29625             0.000000
# 15         1   16629   311417             0.000000
# 16         1   16629    26567             0.000000
# 17         1   16629    53462             0.000000
# 18         1   16629   149458             0.000000
# 19         1   10931   236388             0.000000
# 20         1  115006   171038             0.000000
# 21         1  115006   217404             0.000000
# 22         1  115006    21515             0.000000
# 23         1     149   280049             0.000000
# 24         1     149   248148             0.000000
# 25         1   37405   109101             0.000000
# 26         1   64435   181773             0.000000
# 27         1  128300   187302             0.000000
# 28         1   74305   343563             0.000000
# 29         1   74305   130375             0.000000
# ...      ...     ...      ...                  ...
# 1574641   10   64877   283410             0.000000
# 1574642   10    4749    14676             0.000000
# 1574643   10    1998   361147             0.000000
# 1574644   10  100485   287275             0.000000
# 1574645   10   92179    27485             0.000000
# 1574646   10   92179   151719             0.000000
# 1574647   10   46126   252824             0.000000
# 1574648   10   90014     1296             0.000000
# 1574649   10   51495   214396             0.000000
# 1574650   10  109154    42053             0.000000
# 1574651   10    7837   154333             0.000000
# 1574652   10   80187   178223             0.000000
# 1574653   10   80187   389026             0.000000
# 1574654   10    6611   123392             0.000000
# 1574655   10   22399   282670             0.000000
# 1574656   10   66983   345916             1.183064
# 1574657   10   66983    11728             0.000000
# 1574658   10   66983   372053             1.183064
# 1574659   10   76321   327759             0.000000
# 1574660   10   76321   352802             0.000000
# 1574661   10   20624   364869             0.000000
# 1574662   10  106213   204048             1.183064
# 1574663   10   70406   135843             0.000000
# 1574664   10   99635   254772             0.000000
# 1574665   10   17661   128814             0.000000
# 1574666   10   21604   179760             0.000000
# 1574667   10   73622    36541             0.000000
# 1574668   10  104426    23384             0.000000
# 1574669   10   85674   111923             0.000000
# 1574670   10   11343    52069             0.000000
#
# [1574671 rows x 4 columns]

# %%
# 막피 공격 받은 사람만
rnd_defen = rnd_defen[rnd_defen['random_defender_cnt']>0]
rnd_defen
# Out:
#          day  acc_id  char_id  random_defender_cnt
# 12         1   80158   211359             1.183064
# 31         1   36350    10163             1.183064
# 54         1   74587   338134             1.183064
# 68         1   99016    43078             2.366129
# 110        1  122168   219302             1.183064
# 164        1  101441   378751             3.549193
# 197        1   25924    64642             3.549193
# 198        1   89998   357055             1.183064
# 257        1  112506     3910             1.183064
# 265        1   92418   389423             1.183064
# 279        1  128586   217079             2.366129
# 357        1   28213   271618             5.915322
# 358        1     538   300207             1.183064
# 469        1   24028   184980             1.183064
# 540        1   28068   325745             1.183064
# 578        1  104141   387026             1.183064
# 597        1   74140   384632             1.183064
# 627        1   59921   299538             1.183064
# 637        1   58314   214882             2.366129
# 694        1   78300   138045             1.183064
# 696        1   90356   340453             2.366129
# 717        1   82976    50909             1.183064
# 820        1   29361   179202             1.183064
# 826        1    3231    33946             1.183064
# 859        1      98   205300             1.183064
# 996        1   91056    38874             1.183064
# 1016       1   99787   199851             1.183064
# 1045       1   52849     2855             1.183064
# 1071       1  103468   111893             2.366129
# 1073       1  130414    95122             1.183064
# ...      ...     ...      ...                  ...
# 1574443   10  120158    77961             9.464516
# 1574446   10   95282   217904             4.732258
# 1574448   10   19890   280262             5.915322
# 1574463   10   85691   162952             5.915322
# 1574465   10   84104   216616             1.183064
# 1574468   10   85557     6725             4.732258
# 1574469   10   62974    69237             2.366129
# 1574472   10   26653   367971             1.183064
# 1574478   10   42410   257594             1.183064
# 1574479   10   30877    99823             1.183064
# 1574483   10   90984   368404             3.549193
# 1574501   10   93660   298632             1.183064
# 1574507   10  120039     1839             3.549193
# 1574518   10  125353   350156             1.183064
# 1574522   10   19390   213923             3.549193
# 1574530   10   72157   326334             1.183064
# 1574560   10  122764   271828             1.183064
# 1574575   10   39292   278463             1.183064
# 1574576   10   81159    89464             1.183064
# 1574578   10   40946   174328             1.183064
# 1574583   10   59435    86035             1.183064
# 1574609   10   22284   150990             3.549193
# 1574613   10   19528   240696             1.183064
# 1574616   10  101758   145364             1.183064
# 1574623   10   34847    16802             1.183064
# 1574624   10   70480   162229             3.549193
# 1574634   10     155    89374             2.366129
# 1574656   10   66983   345916             1.183064
# 1574658   10   66983   372053             1.183064
# 1574662   10  106213   204048             1.183064
#
# [77391 rows x 4 columns]

# %%
# 아이디, 날짜 순서로 내림차순 정렬
rnd_defen = rnd_defen.sort_values(['acc_id','day'],ascending=True)
rnd_defen
# Out:
#          day  acc_id  char_id  random_defender_cnt
# 785434    19       8   207949             1.183064
# 420848     7      17   135044             2.366129
# 1263070   28      20   149667             1.183064
# 1416488    6      31   346526             1.183064
# 1431113    9      31   346526             1.183064
# 1311618   11      31   346526             4.732258
# 1316730   12      31   346526             1.183064
# 1321617   13      31   346526             1.183064
# 1336288   16      31   346526             1.183064
# 1341129   17      31   346526             2.366129
# 1370640   22      31   346526             1.183064
# 1375643   23      31   346526             2.366129
# 1390982   26      31   346526             1.183064
# 938647     3      38    67497             1.183064
# 1015982   10      38    67497             1.183064
# 1529773   26      43   388134             1.183064
# 1222019    3      53    60446             1.183064
# 1278007    6      53    60446             4.732258
# 1182468   13      53    60446             1.183064
# 1187452   14      53    60446             1.183064
# 1197299   16      53    60446             1.183064
# 1202279   17      53    60446             1.183064
# 1231942   22      53    60446             1.183064
# 1236932   23      53    60446             1.183064
# 1242002   24      53    60446             1.183064
# 1247237   25      53    60446             1.183064
# 1252555   26      53    60446             1.183064
# 907169    14      54   317400             1.183064
# 962760    24      54   317400             1.183064
# 1284941    8      62   369719             1.183064
# ...      ...     ...      ...                  ...
# 1164811    1  130413   360163             1.183064
# 1169526    2  130413   360163             1.183064
# 1275126    5  130413   360163             1.183064
# 1299188   10  130413   360163             2.366129
# 1174419   11  130413   360163             1.183064
# 1179518   12  130413   360163             2.366129
# 1184410   13  130413   360163             1.183064
# 1189364   14  130413   360163             1.183064
# 1199205   16  130413   360163             1.183064
# 1233911   22  130413   360163             1.183064
# 1249269   25  130413   360163             1.183064
# 1073       1  130414    95122             1.183064
# 176172    14  130447   174980             1.183064
# 365700    21  130449   238395             1.183064
# 397526    27  130449   211697             1.183064
# 564051     6  130462   274672             1.183064
# 574501     8  130462   274672             2.366129
# 584999    10  130462   274672             2.366129
# 542600    27  130462   274672             1.183064
# 922049    17  130463    14261             2.366129
# 927117    18  130463    14261             2.366129
# 947166    21  130463   292737             1.183064
# 952360    22  130463   292737             2.366129
# 962728    24  130463   292737             1.183064
# 968009    25  130463   292737             1.183064
# 874647    10  130469     6255             1.183064
# 791526    20  130469   143384             1.183064
# 490128    18  130470   364642             2.366129
# 500565    20  130470   364642             1.183064
# 1376379   23  130473    96346             1.183064
#
# [77391 rows x 4 columns]

# %%
# 막피를 가장 많이 당한 사람이 누굴까
rnd_defen[ rnd_defen['random_defender_cnt'] ==rnd_defen['random_defender_cnt'].max()]
# Out:
#          day  acc_id  char_id  random_defender_cnt
# 1209205   18   83876   309871           112.391126

# %%
# 후보1 
# 하루 타격이 가장 컸던 유저 95번 맞음   112.391126 /1.183064
rnd_defen[ rnd_defen['acc_id'] ==83876]
# Out:
#          day  acc_id  char_id  random_defender_cnt
# 1270505    4   83876   309871             1.183064
# 1279829    6   83876   309871             2.366129
# 1199295   16   83876   309871             1.183064
# 1204272   17   83876   309871            93.462094
# 1209205   18   83876   309871           112.391126
# 1214202   19   83876   309871            48.505644

# %%
# 후보2 
# 평균적으로 많이 쳐맞음
# 평균은 쳐맞은 일별 평균

rnd_defen[ rnd_defen['acc_id'] ==123532]
# Out:
#         day  acc_id  char_id  random_defender_cnt
# 310117   11  123532   353868            89.912901
# 315330   12  123532   353868            95.828223

# %% [markdown]
# 346526 유저를 봤을 때 누적이 아니다.

# %%
# 쳐맞은 횟수와 타격을 고려한 평균 # 쳐맞은 일별 평균
grp_mean_rnd_defen = rnd_defen.groupby(['acc_id','char_id']).mean()
grp_mean_rnd_defen
# Out:
#                       day  random_defender_cnt
# acc_id char_id
# 8      207949   19.000000             1.183064
# 17     135044    7.000000             2.366129
# 20     149667   28.000000             1.183064
# 31     346526   15.500000             1.774597
# 38     67497     6.500000             1.183064
# 43     388134   26.000000             1.183064
# 53     60446    17.181818             1.505718
# 54     317400   19.000000             1.183064
# 62     369719   10.333333             1.183064
# 67     267831   13.833333             1.380242
# 69     350040   27.000000             1.183064
# 81     297398   22.500000             1.183064
# 91     182545   26.000000             1.183064
#        320252   11.666667             1.183064
# 92     219750   21.000000             2.602742
# 98     205300    1.000000             1.183064
# 100    47156    28.000000             1.183064
# 113    52943    13.000000             1.183064
# 119    136814    7.833333             1.971774
# 129    148992   16.666667             1.183064
# 145    168571   25.000000             1.183064
# 154    142043   16.000000             2.366129
# 155    89374     9.600000             2.129516
# 158    206259   18.000000             1.183064
# 161    169821   26.000000             1.183064
# 163    117291   22.000000             2.366129
#        179915   16.833333             2.168952
# 173    247626   18.000000             1.183064
# 174    142049   13.000000             1.183064
# 176    131026   13.500000             1.183064
# ...                   ...                  ...
# 130342 344996   26.000000             1.183064
# 130345 284905   10.166667             1.380242
# 130349 373445   12.000000             3.549193
# 130354 54178    28.000000             1.183064
# 130356 56150    13.000000             1.183064
#        318206   28.000000             3.549193
# 130363 328452    8.875000             1.330948
# 130376 328729   28.000000             1.183064
# 130391 81082    26.500000             2.366129
# 130392 312455   22.500000             2.957661
# 130398 120669   21.000000             1.183064
#        155430   23.333333             1.183064
# 130401 279722   20.000000             2.070363
# 130403 35017     2.333333             1.971774
#        165204   21.250000             1.774597
# 130405 312566   19.666667             1.183064
#        389504   18.000000             1.183064
# 130408 237182   17.000000             1.183064
# 130413 360163   11.909091             1.398167
# 130414 95122     1.000000             1.183064
# 130447 174980   14.000000             1.183064
# 130449 211697   27.000000             1.183064
#        238395   21.000000             1.183064
# 130462 274672   12.750000             1.774597
# 130463 14261    17.500000             2.366129
#        292737   23.000000             1.478831
# 130469 6255     10.000000             1.183064
#        143384   20.000000             1.183064
# 130470 364642   19.000000             1.774597
# 130473 96346    23.000000             1.183064
#
# [23458 rows x 2 columns]

# %%
grp_mean_rnd_defen_dro_day = grp_mean_rnd_defen.drop(columns = 'day')
grp_mean_rnd_defen_dro_day.sort_values('random_defender_cnt',ascending=False)
# Out:
#                 random_defender_cnt
# acc_id char_id
# 123532 353868             92.870562
# 24761  221277             60.730644
# 15073  89468              50.871773
# 85944  106222             49.215483
# 33320  100251             48.801410
# 30480  114446             48.505644
# 59866  275342             46.731047
# 113806 311787             44.660684
# 83876  309871             43.181854
# 42127  151539             42.826934
# 64294  182353             38.055241
# 95870  104763             35.491935
# 74798  198282             34.815898
# 55111  360493             34.308870
# 7733   302161             32.618778
# 14271  295886             31.351209
# 71015  190687             31.266704
# 27938  264378             29.576612
# 26519  170677             27.802015
# 82066  276291             26.196428
# 30281  277854             26.027419
# 65218  247842             24.844354
# 26932  122647             23.266935
# 79303  177197             22.478225
# 63278  47084              22.140207
# 122533 43880              21.633179
# 115511 257366             21.058548
# 54360  149828             20.259979
# 74388  240529             19.964213
# 10284  396384             19.638870
# ...                             ...
# 58092  350924              1.183064
# 58422  267515              1.183064
# 58096  232755              1.183064
# 58099  158596              1.183064
# 58113  223249              1.183064
# 58119  153166              1.183064
# 58140  299148              1.183064
# 58146  23792               1.183064
#        375205              1.183064
# 58164  91267               1.183064
# 58185  200335              1.183064
# 58204  299415              1.183064
# 58210  65659               1.183064
# 58216  81473               1.183064
# 58239  327950              1.183064
# 58248  246048              1.183064
# 58255  35989               1.183064
# 58268  95164               1.183064
# 58284  238174              1.183064
# 58320  387875              1.183064
# 58328  161552              1.183064
# 58335  334694              1.183064
# 58358  253342              1.183064
# 58366  91092               1.183064
#        272801              1.183064
# 58400  373073              1.183064
# 58406  246532              1.183064
# 58416  33029               1.183064
# 58419  123485              1.183064
# 130473 96346               1.183064
#
# [23458 rows x 1 columns]

# %%
# 모든 유저에게 같은 일수로 나누자

# %%
# 많이 쳐맞은 사람이 이탈했을까
label = pd.read_csv('BigContest/train_label.csv')

# %%
label.dtypes
# Out:
# acc_id             int64
# survival_time      int64
# amount_spent     float64
# dtype: object

# %%
label[label['acc_id']==123532]
# Out:
#        acc_id  survival_time  amount_spent
# 34897  123532             64      0.001542

# %%
# 와우 생존

# %%
label[label['acc_id']==83876]
# Out:
#        acc_id  survival_time  amount_spent
# 37579   83876             64           0.0

# %%
#와우 이사람도 생존

# %%
label[label['acc_id']==130473]
# Out:
#        acc_id  survival_time  amount_spent
# 21906  130473             64       0.55198

# %%
# 뭐지 낮은 사람도 생존

# %%
# 총량으로 하자
grp_sum_rnd_defen = rnd_defen.groupby(['acc_id','char_id']).sum().sort_values('random_defender_cnt',ascending=False).drop(columns='day')
grp_sum_rnd_defen
# Out:
#                 random_defender_cnt
# acc_id char_id
# 52326  170705            301.681444
# 85670  318552            263.823380
# 83876  309871            259.091122
# 9505   253723            249.626606
# 120158 77961             248.443542
# 13635  215770            248.443542
# 85944  106222            246.077413
# 74798  198282            243.711284
# 115690 157477            242.528219
# 55111  360493            240.162090
# 1764   56884             234.246768
# 64294  182353            228.331446
# 7733   302161            228.331446
# 71015  190687            218.866930
# 24358  24609             216.500801
# 119323 160169            216.500801
# 42127  151539            214.134672
# 126008 708               207.036285
# 49497  194367            207.036285
# 19890  280262            201.120962
# 33320  100251            195.205640
# 30480  114446            194.022576
# 99742  339398            188.107253
# 59866  275342            186.924189
# 123532 353868            185.741124
# 82066  276291            183.374995
# 47615  107471            182.191931
# 24761  221277            182.191931
# 113806 311787            178.642737
# 95870  104763            177.459673
# ...                             ...
# 65895  157838              1.183064
# 65913  377435              1.183064
# 65965  18461               1.183064
# 65972  112902              1.183064
# 65975  366488              1.183064
# 65981  155563              1.183064
# 65995  73323               1.183064
# 65513  202083              1.183064
# 65484  321582              1.183064
# 65433  386177              1.183064
# 65296  21205               1.183064
# 65110  184323              1.183064
# 65134  149520              1.183064
# 65137  43619               1.183064
# 65144  319739              1.183064
# 65183  330823              1.183064
# 65254  248674              1.183064
#        308119              1.183064
# 65262  35692               1.183064
# 65310  5074                1.183064
# 65424  123932              1.183064
# 65318  113909              1.183064
# 65373  72537               1.183064
# 65374  47586               1.183064
# 65385  142156              1.183064
# 65393  174098              1.183064
# 65400  124009              1.183064
# 65401  377642              1.183064
# 65409  136327              1.183064
# 130473 96346               1.183064
#
# [23458 rows x 1 columns]

# %%
# 새로운 인물 등장

# %%
label[label['acc_id']==52326]
# Out:
#        acc_id  survival_time  amount_spent
# 25066   52326             64           0.0

# %%
#오 대박 생존

# %%
sum_mrg= pd.merge(grp_sum_rnd_defen,label, how = 'inner', on = 'acc_id').sort_values('random_defender_cnt',ascending=False).drop(columns='amount_spent')

sum_mrg
# Out:
#        acc_id  random_defender_cnt  survival_time
# 0       52326           301.681444             64
# 1       85670           263.823380             36
# 3       83876           259.091122             64
# 4        9505           249.626606             36
# 7      120158           248.443542             15
# 8       13635           248.443542             64
# 9       85944           246.077413             64
# 10      74798           243.711284             64
# 11     115690           242.528219              8
# 12      55111           240.162090             64
# 13       1764           234.246768             64
# 14      64294           228.331446             64
# 15       7733           228.331446             64
# 16      71015           218.866930             64
# 18     119323           216.500801             64
# 17      24358           216.500801             64
# 19      42127           214.134672             64
# 20     126008           207.036285             64
# 21      49497           207.036285             64
# 22      19890           201.120962             22
# 23      33320           195.205640             64
# 24      30480           194.022576             64
# 25      99742           188.107253             64
# 26      59866           186.924189             64
# 27     123532           185.741124             64
# 28      82066           183.374995             64
# 29      47615           182.191931             64
# 30      24761           182.191931             64
# 31     113806           178.642737             64
# 32      95870           177.459673             64
# ...       ...                  ...            ...
# 18243  128156             1.183064             64
# 18244  112055             1.183064             36
# 18259  118964             1.183064             64
# 18271  101289             1.183064             64
# 18270  128408             1.183064             64
# 18269  101134             1.183064             64
# 18268  123908             1.183064             58
# 18267  115732             1.183064             64
# 18266  123912             1.183064             64
# 18265  107739             1.183064             64
# 18264  115718             1.183064              6
# 18263  112093             1.183064             64
# 18262  128026             1.183064              3
# 18261  115710             1.183064             64
# 18260  128021             1.183064             55
# 18258  112097             1.183064             39
# 18245  101131             1.183064             64
# 18257  107700             1.183064             64
# 18256  118938             1.183064             64
# 18255  128058             1.183064             64
# 18254  107741             1.183064             64
# 18253  107741             1.183064             64
# 18252  101036             1.183064             64
# 18251  112042             1.183064             23
# 18250  112044             1.183064             30
# 18249  107764             1.183064             64
# 18248  115783             1.183064             23
# 18247  118896             1.183064             64
# 18246  101088             1.183064             16
# 23457  130473             1.183064             64
#
# [23458 rows x 3 columns]

# %%
rdm_defcnt=sum_mrg[['random_defender_cnt']]
rdm_defcnt
# Out:
#        random_defender_cnt
# 0               301.681444
# 1               263.823380
# 3               259.091122
# 4               249.626606
# 7               248.443542
# 8               248.443542
# 9               246.077413
# 10              243.711284
# 11              242.528219
# 12              240.162090
# 13              234.246768
# 14              228.331446
# 15              228.331446
# 16              218.866930
# 18              216.500801
# 17              216.500801
# 19              214.134672
# 20              207.036285
# 21              207.036285
# 22              201.120962
# 23              195.205640
# 24              194.022576
# 25              188.107253
# 26              186.924189
# 27              185.741124
# 28              183.374995
# 29              182.191931
# 30              182.191931
# 31              178.642737
# 32              177.459673
# ...                    ...
# 18243             1.183064
# 18244             1.183064
# 18259             1.183064
# 18271             1.183064
# 18270             1.183064
# 18269             1.183064
# 18268             1.183064
# 18267             1.183064
# 18266             1.183064
# 18265             1.183064
# 18264             1.183064
# 18263             1.183064
# 18262             1.183064
# 18261             1.183064
# 18260             1.183064
# 18258             1.183064
# 18245             1.183064
# 18257             1.183064
# 18256             1.183064
# 18255             1.183064
# 18254             1.183064
# 18253             1.183064
# 18252             1.183064
# 18251             1.183064
# 18250             1.183064
# 18249             1.183064
# 18248             1.183064
# 18247             1.183064
# 18246             1.183064
# 23457             1.183064
#
# [23458 rows x 1 columns]

# %%
srv_tm=sum_mrg[['survival_time']]
srv_tm
# Out:
#        survival_time
# 0                 64
# 1                 36
# 3                 64
# 4                 36
# 7                 15
# 8                 64
# 9                 64
# 10                64
# 11                 8
# 12                64
# 13                64
# 14                64
# 15                64
# 16                64
# 18                64
# 17                64
# 19                64
# 20                64
# 21                64
# 22                22
# 23                64
# 24                64
# 25                64
# 26                64
# 27                64
# 28                64
# 29                64
# 30                64
# 31                64
# 32                64
# ...              ...
# 18243             64
# 18244             36
# 18259             64
# 18271             64
# 18270             64
# 18269             64
# 18268             58
# 18267             64
# 18266             64
# 18265             64
# 18264              6
# 18263             64
# 18262              3
# 18261             64
# 18260             55
# 18258             39
# 18245             64
# 18257             64
# 18256             64
# 18255             64
# 18254             64
# 18253             64
# 18252             64
# 18251             23
# 18250             30
# 18249             64
# 18248             23
# 18247             64
# 18246             16
# 23457             64
#
# [23458 rows x 1 columns]

# %%
srv_tm['survival_time']
# Out:
# 0        64
# 1        36
# 3        64
# 4        36
# 7        15
# 8        64
# 9        64
# 10       64
# 11        8
# 12       64
# 13       64
# 14       64
# 15       64
# 16       64
# 18       64
# 17       64
# 19       64
# 20       64
# 21       64
# 22       22
# 23       64
# 24       64
# 25       64
# 26       64
# 27       64
# 28       64
# 29       64
# 30       64
# 31       64
# 32       64
#          ..
# 18243    64
# 18244    36
# 18259    64
# 18271    64
# 18270    64
# 18269    64
# 18268    58
# 18267    64
# 18266    64
# 18265    64
# 18264     6
# 18263    64
# 18262     3
# 18261    64
# 18260    55
# 18258    39
# 18245    64
# 18257    64
# 18256    64
# 18255    64
# 18254    64
# 18253    64
# 18252    64
# 18251    23
# 18250    30
# 18249    64
# 18248    23
# 18247    64
# 18246    16
# 23457    64
# Name: survival_time, Length: 23458, dtype: int64

# %%
grp_df = pd.DataFrame({'survival_time':srv_tm['survival_time'], 'random_defender_cnt':rdm_defcnt['random_defender_cnt']})

# %%
grp_df.plot.scatter(x='survival_time',y='random_defender_cnt')

# %%
# 10일 살았던 사람이나, 15일 살았던 사람이나, 30일 살았던 사람이나, 40일 살았던 사람이나 맞은 횟수는 비슷하다.
#오히려 64일 이상 생존했던 사람들이 많이 맞았다
#그만큼 많이 때렸겠지?
# 서로 때리며 다독이는 걸까

# %% [markdown]
# -------------------------------------------------------------------------------
# --------------------------------------------------------------------------------

# %%
combat.corr()
# Out:
#                           day    acc_id   char_id     class     level  \
# day                  1.000000 -0.000261  0.001296  0.003640  0.008160
# acc_id              -0.000261  1.000000 -0.002049 -0.002835 -0.003309
# char_id              0.001296 -0.002049  1.000000 -0.006814  0.003334
# class                0.003640 -0.002835 -0.006814  1.000000 -0.005440
# level                0.008160 -0.003309  0.003334 -0.005440  1.000000
# pledge_cnt           0.004368 -0.000439 -0.003199  0.012492  0.116130
# random_attacker_cnt  0.000181  0.001797  0.003306  0.003114  0.032739
# random_defender_cnt  0.003016 -0.001280  0.001459  0.003799  0.085389
# temp_cnt             0.002980 -0.000167 -0.002165  0.002119  0.041260
# same_pledge_cnt     -0.026159  0.000672  0.000530  0.004602  0.037253
# etc_cnt             -0.002408  0.002673  0.005881  0.017178  0.112814
# num_opponent         0.000427  0.002151 -0.000752  0.023045  0.170594
#
#                      pledge_cnt  random_attacker_cnt  random_defender_cnt  \
# day                    0.004368             0.000181             0.003016
# acc_id                -0.000439             0.001797            -0.001280
# char_id               -0.003199             0.003306             0.001459
# class                  0.012492             0.003114             0.003799
# level                  0.116130             0.032739             0.085389
# pledge_cnt             1.000000             0.026830             0.029669
# random_attacker_cnt    0.026830             1.000000            -0.006448
# random_defender_cnt    0.029669            -0.006448             1.000000
# temp_cnt               0.006668            -0.003371             0.010615
# same_pledge_cnt        0.056612             0.018152             0.003205
# etc_cnt                0.192308            -0.008527             0.030314
# num_opponent           0.853163             0.132736             0.049738
#
#                      temp_cnt  same_pledge_cnt   etc_cnt  num_opponent
# day                  0.002980        -0.026159 -0.002408      0.000427
# acc_id              -0.000167         0.000672  0.002673      0.002151
# char_id             -0.002165         0.000530  0.005881     -0.000752
# class                0.002119         0.004602  0.017178      0.023045
# level                0.041260         0.037253  0.112814      0.170594
# pledge_cnt           0.006668         0.056612  0.192308      0.853163
# random_attacker_cnt -0.003371         0.018152 -0.008527      0.132736
# random_defender_cnt  0.010615         0.003205  0.030314      0.049738
# temp_cnt             1.000000         0.003694 -0.004306      0.012463
# same_pledge_cnt      0.003694         1.000000  0.034748      0.078746
# etc_cnt             -0.004306         0.034748  1.000000      0.453074
# num_opponent         0.012463         0.078746  0.453074      1.000000

# %%
result =pd.merge(combat,label,how='inner',on='acc_id').corr()
result
result.corr()
# Out:
#                           day    acc_id   char_id     class     level  \
# day                  1.000000 -0.075857 -0.072393 -0.067912 -0.099749
# acc_id              -0.075857  1.000000 -0.081614 -0.084539 -0.128752
# char_id             -0.072393 -0.081614  1.000000 -0.093069 -0.114355
# class               -0.067912 -0.084539 -0.093069  1.000000 -0.124018
# level               -0.099749 -0.128752 -0.114355 -0.124018  1.000000
# pledge_cnt          -0.139650 -0.148974 -0.154775 -0.112079  0.122998
# random_attacker_cnt -0.091371 -0.090076 -0.087068 -0.085787 -0.049724
# random_defender_cnt -0.079913 -0.093441 -0.086902 -0.080398  0.065068
# temp_cnt            -0.074383 -0.083818 -0.087839 -0.080113 -0.037817
# same_pledge_cnt     -0.149592 -0.094105 -0.094433 -0.084300 -0.041627
# etc_cnt             -0.134998 -0.129125 -0.123540 -0.088830  0.130530
# num_opponent        -0.171085 -0.173665 -0.178334 -0.125751  0.162979
# survival_time       -0.103886 -0.061285 -0.064777 -0.144124 -0.256310
# amount_spent        -0.073159 -0.071535 -0.078130 -0.074456 -0.031137
#
#                      pledge_cnt  random_attacker_cnt  random_defender_cnt  \
# day                   -0.139650            -0.091371            -0.079913
# acc_id                -0.148974            -0.090076            -0.093441
# char_id               -0.154775            -0.087068            -0.086902
# class                 -0.112079            -0.085787            -0.080398
# level                  0.122998            -0.049724             0.065068
# pledge_cnt             1.000000            -0.031434            -0.073072
# random_attacker_cnt   -0.031434             1.000000            -0.113656
# random_defender_cnt   -0.073072            -0.113656             1.000000
# temp_cnt              -0.136320            -0.105293            -0.069913
# same_pledge_cnt       -0.014003            -0.062550            -0.094660
# etc_cnt                0.400852            -0.110193            -0.055633
# num_opponent           0.960471             0.039705            -0.075546
# survival_time         -0.009303            -0.060142            -0.154306
# amount_spent          -0.085307            -0.079730            -0.103445
#
#                      temp_cnt  same_pledge_cnt   etc_cnt  num_opponent  \
# day                 -0.074383        -0.149592 -0.134998     -0.171085
# acc_id              -0.083818        -0.094105 -0.129125     -0.173665
# char_id             -0.087839        -0.094433 -0.123540     -0.178334
# class               -0.080113        -0.084300 -0.088830     -0.125751
# level               -0.037817        -0.041627  0.130530      0.162979
# pledge_cnt          -0.136320        -0.014003  0.400852      0.960471
# random_attacker_cnt -0.105293        -0.062550 -0.110193      0.039705
# random_defender_cnt -0.069913        -0.094660 -0.055633     -0.075546
# temp_cnt             1.000000        -0.092177 -0.142038     -0.159883
# same_pledge_cnt     -0.092177         1.000000 -0.041972     -0.016182
# etc_cnt             -0.142038        -0.041972  1.000000      0.600446
# num_opponent        -0.159883        -0.016182  0.600446      1.000000
# survival_time       -0.059867        -0.064194 -0.104658     -0.050153
# amount_spent        -0.085458        -0.074626 -0.104555     -0.109354
#
#                      survival_time  amount_spent
# day                      -0.103886     -0.073159
# acc_id                   -0.061285     -0.071535
# char_id                  -0.064777     -0.078130
# class                    -0.144124     -0.074456
# level                    -0.256310     -0.031137
# pledge_cnt               -0.009303     -0.085307
# random_attacker_cnt      -0.060142     -0.079730
# random_defender_cnt      -0.154306     -0.103445
# temp_cnt                 -0.059867     -0.085458
# same_pledge_cnt          -0.064194     -0.074626
# etc_cnt                  -0.104658     -0.104555
# num_opponent             -0.050153     -0.109354
# survival_time             1.000000     -0.235635
# amount_spent             -0.235635      1.000000

# %%
print(type(result))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# combat = pd.read_csv('BigContest/train_combat.csv')
# combat = pd.read_csv('BigContest/train_combat.csv')
# label
payment = pd.read_csv('BigContest/train_payment.csv')
pledge = pd.read_csv('BigContest/train_pledge.csv')
trade = pd.read_csv('BigContest/train_trade.csv')

# %%
result2 = pd.merge(payment,label,how='inner',on='acc_id').corr()

# %%
result3 = pd.merge(pledge,label,how='inner',on='acc_id').corr()

# %%
trade = trade.rename(columns={"source_acc_id": "acc_id"})

# %%
result4 = pd.merge(trade,label,how='inner',on='acc_id').corr()

# %%
result2.corr()[result2.corr()>0]
# Out:
#                 day  acc_id  amount_spent_x  survival_time  amount_spent_y
# day             1.0     NaN             NaN            NaN             NaN
# acc_id          NaN     1.0             NaN            NaN             NaN
# amount_spent_x  NaN     NaN             1.0            NaN             NaN
# survival_time   NaN     NaN             NaN            1.0             NaN
# amount_spent_y  NaN     NaN             NaN            NaN             1.0

# %%
result3.corr()
# Out:
#                            day    acc_id   char_id  pledge_id  play_char_cnt  \
# day                   1.000000 -0.055458 -0.049221  -0.057760      -0.242082
# acc_id               -0.055458  1.000000 -0.069855  -0.066654      -0.223019
# char_id              -0.049221 -0.069855  1.000000  -0.088493      -0.221365
# pledge_id            -0.057760 -0.066654 -0.088493   1.000000      -0.249651
# play_char_cnt        -0.242082 -0.223019 -0.221365  -0.249651       1.000000
# combat_char_cnt      -0.257204 -0.238296 -0.238090  -0.227153       0.932497
# pledge_combat_cnt    -0.168871 -0.170642 -0.178394  -0.105147       0.266639
# random_attacker_cnt  -0.210992 -0.177796 -0.180866  -0.193957       0.526560
# random_defender_cnt  -0.101805 -0.136216 -0.115392  -0.054206       0.229535
# same_pledge_cnt      -0.419804 -0.166456 -0.172992  -0.189965       0.516482
# temp_cnt             -0.184672 -0.207104 -0.207916  -0.244488       0.872480
# etc_cnt              -0.223250 -0.200766 -0.202718  -0.172000       0.753793
# combat_play_time     -0.241689 -0.227636 -0.223578  -0.206664       0.933662
# non_combat_play_time  0.001309 -0.024030 -0.017100   0.003603      -0.383786
# survival_time        -0.086640 -0.048787 -0.057688  -0.039532      -0.231451
# amount_spent         -0.068349 -0.084847 -0.077338  -0.069802      -0.094091
#
#                       combat_char_cnt  pledge_combat_cnt  random_attacker_cnt  \
# day                         -0.257204          -0.168871            -0.210992
# acc_id                      -0.238296          -0.170642            -0.177796
# char_id                     -0.238090          -0.178394            -0.180866
# pledge_id                   -0.227153          -0.105147            -0.193957
# play_char_cnt                0.932497           0.266639             0.526560
# combat_char_cnt              1.000000           0.486932             0.505751
# pledge_combat_cnt            0.486932           1.000000             0.174866
# random_attacker_cnt          0.505751           0.174866             1.000000
# random_defender_cnt          0.230146          -0.021129             0.018730
# same_pledge_cnt              0.516479           0.234281             0.348396
# temp_cnt                     0.790919           0.224813             0.480050
# etc_cnt                      0.913072           0.505876             0.377100
# combat_play_time             0.934792           0.313439             0.482372
# non_combat_play_time        -0.442458          -0.252488            -0.285998
# survival_time               -0.232013          -0.026702            -0.090111
# amount_spent                -0.088918          -0.049152            -0.091539
#
#                       random_defender_cnt  same_pledge_cnt  temp_cnt  \
# day                             -0.101805        -0.419804 -0.184672
# acc_id                          -0.136216        -0.166456 -0.207104
# char_id                         -0.115392        -0.172992 -0.207916
# pledge_id                       -0.054206        -0.189965 -0.244488
# play_char_cnt                    0.229535         0.516482  0.872480
# combat_char_cnt                  0.230146         0.516479  0.790919
# pledge_combat_cnt               -0.021129         0.234281  0.224813
# random_attacker_cnt              0.018730         0.348396  0.480050
# random_defender_cnt              1.000000         0.013403  0.145253
# same_pledge_cnt                  0.013403         1.000000  0.430521
# temp_cnt                         0.145253         0.430521  1.000000
# etc_cnt                          0.045945         0.456515  0.585922
# combat_play_time                 0.337918         0.524372  0.789401
# non_combat_play_time            -0.189182        -0.266531 -0.389470
# survival_time                   -0.219469        -0.082345 -0.145816
# amount_spent                    -0.091306        -0.077838 -0.104107
#
#                        etc_cnt  combat_play_time  non_combat_play_time  \
# day                  -0.223250         -0.241689              0.001309
# acc_id               -0.200766         -0.227636             -0.024030
# char_id              -0.202718         -0.223578             -0.017100
# pledge_id            -0.172000         -0.206664              0.003603
# play_char_cnt         0.753793          0.933662             -0.383786
# combat_char_cnt       0.913072          0.934792             -0.442458
# pledge_combat_cnt     0.505876          0.313439             -0.252488
# random_attacker_cnt   0.377100          0.482372             -0.285998
# random_defender_cnt   0.045945          0.337918             -0.189182
# same_pledge_cnt       0.456515          0.524372             -0.266531
# temp_cnt              0.585922          0.789401             -0.389470
# etc_cnt               1.000000          0.800962             -0.363874
# combat_play_time      0.800962          1.000000             -0.449250
# non_combat_play_time -0.363874         -0.449250              1.000000
# survival_time        -0.206277         -0.249348             -0.137635
# amount_spent         -0.071503         -0.104071             -0.117078
#
#                       survival_time  amount_spent
# day                       -0.086640     -0.068349
# acc_id                    -0.048787     -0.084847
# char_id                   -0.057688     -0.077338
# pledge_id                 -0.039532     -0.069802
# play_char_cnt             -0.231451     -0.094091
# combat_char_cnt           -0.232013     -0.088918
# pledge_combat_cnt         -0.026702     -0.049152
# random_attacker_cnt       -0.090111     -0.091539
# random_defender_cnt       -0.219469     -0.091306
# same_pledge_cnt           -0.082345     -0.077838
# temp_cnt                  -0.145816     -0.104107
# etc_cnt                   -0.206277     -0.071503
# combat_play_time          -0.249348     -0.104071
# non_combat_play_time      -0.137635     -0.117078
# survival_time              1.000000     -0.199271
# amount_spent              -0.199271      1.000000

# %%
result4.corr()[result4.corr()>0]
# Out:
#                 day      type  acc_id  source_char_id  target_acc_id  \
# day             1.0       NaN     NaN             NaN            NaN
# type            NaN  1.000000     NaN             NaN            NaN
# acc_id          NaN       NaN     1.0             NaN            NaN
# source_char_id  NaN       NaN     NaN             1.0            NaN
# target_acc_id   NaN       NaN     NaN             NaN            1.0
# target_char_id  NaN       NaN     NaN             NaN            NaN
# item_amount     NaN  0.178509     NaN             NaN            NaN
# item_price      NaN       NaN     NaN             NaN            NaN
# survival_time   NaN       NaN     NaN             NaN            NaN
# amount_spent    NaN       NaN     NaN             NaN            NaN
#
#                 target_char_id  item_amount  item_price  survival_time  \
# day                        NaN          NaN         NaN            NaN
# type                       NaN     0.178509         NaN            NaN
# acc_id                     NaN          NaN         NaN            NaN
# source_char_id             NaN          NaN         NaN            NaN
# target_acc_id              NaN          NaN         NaN            NaN
# target_char_id             1.0          NaN         NaN            NaN
# item_amount                NaN     1.000000         NaN            NaN
# item_price                 NaN          NaN         1.0            NaN
# survival_time              NaN          NaN         NaN            1.0
# amount_spent               NaN          NaN         NaN            NaN
#
#                 amount_spent
# day                      NaN
# type                     NaN
# acc_id                   NaN
# source_char_id           NaN
# target_acc_id            NaN
# target_char_id           NaN
# item_amount              NaN
# item_price               NaN
# survival_time            NaN
# amount_spent             1.0

# %%
activity = pd.read_csv('BigContest/train_activity.csv')
result5 =pd.merge(activity,label,how='inner',on='acc_id').corr()

# %%
result5.corr()[result5.corr()>0]
# Out:
#                         day  acc_id  char_id  playtime  npc_kill  solo_exp  \
# day                1.000000     NaN      NaN       NaN       NaN       NaN
# acc_id                  NaN     1.0      NaN       NaN       NaN       NaN
# char_id                 NaN     NaN      1.0       NaN       NaN       NaN
# playtime                NaN     NaN      NaN  1.000000  0.342576       NaN
# npc_kill                NaN     NaN      NaN  0.342576  1.000000  0.262690
# solo_exp                NaN     NaN      NaN       NaN  0.262690  1.000000
# party_exp               NaN     NaN      NaN       NaN       NaN  0.056940
# quest_exp               NaN     NaN      NaN       NaN       NaN  0.573962
# boss_monster            NaN     NaN      NaN       NaN  0.208735  0.117823
# death                   NaN     NaN      NaN       NaN       NaN       NaN
# revive                  NaN     NaN      NaN       NaN       NaN       NaN
# exp_recovery            NaN     NaN      NaN       NaN       NaN       NaN
# fishing                 NaN     NaN      NaN  0.399575  0.160906       NaN
# private_shop       0.005387     NaN      NaN  0.667187       NaN       NaN
# game_money_change       NaN     NaN      NaN       NaN       NaN       NaN
# enchant_count           NaN     NaN      NaN       NaN       NaN       NaN
# survival_time           NaN     NaN      NaN  0.042904       NaN       NaN
# amount_spent            NaN     NaN      NaN       NaN       NaN       NaN
#
#                    party_exp  quest_exp  boss_monster     death    revive  \
# day                      NaN        NaN           NaN       NaN       NaN
# acc_id                   NaN        NaN           NaN       NaN       NaN
# char_id                  NaN        NaN           NaN       NaN       NaN
# playtime                 NaN        NaN           NaN       NaN       NaN
# npc_kill                 NaN        NaN      0.208735       NaN       NaN
# solo_exp            0.056940   0.573962      0.117823       NaN       NaN
# party_exp           1.000000   0.049031           NaN  0.001828       NaN
# quest_exp           0.049031   1.000000      0.014427       NaN       NaN
# boss_monster             NaN   0.014427      1.000000       NaN       NaN
# death               0.001828        NaN           NaN  1.000000  0.999922
# revive                   NaN        NaN           NaN  0.999922  1.000000
# exp_recovery             NaN        NaN      0.002286       NaN       NaN
# fishing                  NaN        NaN      0.239849       NaN       NaN
# private_shop             NaN        NaN           NaN       NaN       NaN
# game_money_change        NaN        NaN           NaN       NaN       NaN
# enchant_count            NaN        NaN           NaN       NaN       NaN
# survival_time            NaN        NaN           NaN       NaN       NaN
# amount_spent             NaN        NaN           NaN       NaN       NaN
#
#                    exp_recovery   fishing  private_shop  game_money_change  \
# day                         NaN       NaN      0.005387                NaN
# acc_id                      NaN       NaN           NaN                NaN
# char_id                     NaN       NaN           NaN                NaN
# playtime                    NaN  0.399575      0.667187                NaN
# npc_kill                    NaN  0.160906           NaN                NaN
# solo_exp                    NaN       NaN           NaN                NaN
# party_exp                   NaN       NaN           NaN                NaN
# quest_exp                   NaN       NaN           NaN                NaN
# boss_monster           0.002286  0.239849           NaN                NaN
# death                       NaN       NaN           NaN                NaN
# revive                      NaN       NaN           NaN                NaN
# exp_recovery           1.000000       NaN           NaN                NaN
# fishing                     NaN  1.000000           NaN                NaN
# private_shop                NaN       NaN      1.000000                NaN
# game_money_change           NaN       NaN           NaN                1.0
# enchant_count               NaN       NaN           NaN                NaN
# survival_time               NaN  0.093602      0.217359                NaN
# amount_spent                NaN       NaN           NaN                NaN
#
#                    enchant_count  survival_time  amount_spent
# day                          NaN            NaN           NaN
# acc_id                       NaN            NaN           NaN
# char_id                      NaN            NaN           NaN
# playtime                     NaN       0.042904           NaN
# npc_kill                     NaN            NaN           NaN
# solo_exp                     NaN            NaN           NaN
# party_exp                    NaN            NaN           NaN
# quest_exp                    NaN            NaN           NaN
# boss_monster                 NaN            NaN           NaN
# death                        NaN            NaN           NaN
# revive                       NaN            NaN           NaN
# exp_recovery                 NaN            NaN           NaN
# fishing                      NaN       0.093602           NaN
# private_shop                 NaN       0.217359           NaN
# game_money_change            NaN            NaN           NaN
# enchant_count                1.0            NaN           NaN
# survival_time                NaN       1.000000           NaN
# amount_spent                 NaN            NaN           1.0

# %%
# 실습에 필요한 패키지입니다. 수정하지 마세요.

import matplotlib as mpl
mpl.use("Agg")
import matplotlib.pyplot as plt
import numpy as np


# 실습에 필요한 데이터입니다. 수정하지마세요. 
X = [8.70153760, 3.90825773, 1.89362433, 3.28730045, 7.39333004, 2.98984649, 2.25757240, 9.84450732, 9.94589513, 5.48321616]
Y = [5.64413093, 3.75876583, 3.87233310, 4.40990425, 6.43845020, 4.02827829, 2.26105955, 7.15768995, 6.29097441, 5.19692852]

type(X)
'''
beta_0과 beta_1 을 변경하면서 그래프에 표시되는 선을 확인해 봅니다.
기울기와 절편의 의미를 이해합니다.
'''

beta_0 = 0.5   # beta_0에 저장된 기울기 값을 조정해보세요. 
beta_1 = 2 # beta_1에 저장된 절편 값을 조정해보세요.

plt.scatter(X, Y) # (x, y) 점을 그립니다.
plt.plot([0, 10], [beta_1, 10 * beta_0 + beta_1], c='r') # y = beta_0 * x + beta_1 에 해당하는 선을 그립니다.

plt.xlim(0, 10) # 그래프의 X축을 설정합니다.
plt.ylim(0, 10) # 그래프의 Y축을 설정합니다.

# 엘리스에 이미지를 표시합니다.
plt.savefig("test.png")

# %%
import matplotlib as mpl
mpl.use("Agg")
import matplotlib.pyplot as plt
import numpy as np


def loss(x, y, beta_0, beta_1):
    N = len(x)
    
    '''
    x, y, beta_0, beta_1 을 이용해 loss값을 계산한 뒤 리턴합니다.
    '''
    total_loss = 0
    for i in range(N):
        y_i = y[i]
        x_i = x[i]
        y_predicted = beta_0 * x_i + beta_1
        
        diff = (y_i - y_predicted) **2
        total_loss += diff
        
    return total_loss

X = [8.70153760, 3.90825773, 1.89362433, 3.28730045, 7.39333004, 2.98984649, 2.25757240, 9.84450732, 9.94589513, 5.48321616]
Y = [5.64413093, 3.75876583, 3.87233310, 4.40990425, 6.43845020, 4.02827829, 2.26105955, 7.15768995, 6.29097441, 5.19692852]

beta_0 = 1 # 기울기
beta_1 = 0.5 # 절편

print("Loss: %f" % loss(X, Y, beta_0, beta_1))

plt.scatter(X, Y) # (x, y) 점을 그립니다.
plt.plot([0, 10], [beta_1, 10 * beta_0 + beta_1], c='r') # y = beta_0 * x + beta_1 에 해당하는 선을 그립니다.

plt.xlim(0, 10) # 그래프의 X축을 설정합니다.
plt.ylim(0, 10) # 그래프의 Y축을 설정합니다.
plt.savefig("test.png") # 저장 후 엘리스에 이미지를 표시합니다.
# Out:
# Loss: 46.341726

# %%
import matplotlib as mpl
mpl.use("Agg")
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression  #Scikit-learn



def loss(x, y, beta_0, beta_1):
    N = len(x)
    
    '''
    이전 실습에서 구현한 loss function을 여기에 붙여넣습니다.
    '''
    total_loss = 0
    for i in range(N):
        y_i = y[i]
        x_i = x[i]
        y_predicted = beta_0 * x_i + beta_1
        
        diff = (y_i - y_predicted) **2
        total_loss += diff
        
    return total_loss
    
    return 0
    
X = [8.70153760, 3.90825773, 1.89362433, 3.28730045, 7.39333004, 2.98984649, 2.25757240, 9.84450732, 9.94589513, 5.48321616]
Y = [5.64413093, 3.75876583, 3.87233310, 4.40990425, 6.43845020, 4.02827829, 2.26105955, 7.15768995, 6.29097441, 5.19692852]

train_X = np.array(X).reshape(-1, 1)
train_Y = np.array(Y)

'''
여기에서 모델을 트레이닝합니다.
'''
lrmodel = LinearRegression()
lrmodel.fit(train_X, train_Y)

beta_0 = lrmodel.coef_[0]
beta_1 = lrmodel.intercept_

print("beta_0: %f" % beta_0)
print("beta_1: %f" % beta_1)
print("Loss: %f" % loss(X, Y, beta_0, beta_1))

plt.scatter(X, Y) # (x, y) 점을 그립니다.
plt.plot([0, 10], [beta_1, 10 * beta_0 + beta_1], c='r') # y = beta_0 * x + beta_1 에 해당하는 선을 그립니다.

plt.xlim(0, 10) # 그래프의 X축을 설정합니다.
plt.ylim(0, 10) # 그래프의 Y축을 설정합니다.
plt.savefig("test.png") # 저장 후 엘리스에 이미지를 표시합니다.
# Out:
# beta_0: 0.430781
# beta_1: 2.506181
# Loss: 3.721640
